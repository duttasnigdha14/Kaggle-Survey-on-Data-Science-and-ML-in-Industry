# %% [markdown]
# # Data Science and MLOps Landscape in Industry

# %% [markdown]
# In September 2022, Kaggle conducted its sixth annual industry-wide survey in an attempt to surface a truly comprehensive view of the state of data science and machine learning.

# %% [markdown]
# As we know, the world of Artificial Intelligence just begins. With the powerful weapon like AI

# %% [markdown]
# #### Load the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
survey_raw=pd.read_csv('E:\\Kaggle Survey\\kaggle_survey_2022_responses.csv')
# Out:
# C:\Users\sdutt\AppData\Local\Temp\ipykernel_13292\2725944499.py:1: DtypeWarning: Columns (0,208,225,255,257,260,270,271,277) have mixed types. Specify dtype option on import or set low_memory=False.
#   survey_raw=pd.read_csv('E:\\Kaggle Survey\\kaggle_survey_2022_responses.csv')

# %%
survey_raw
# Out:
#        Duration (in seconds)                           Q2  \
# 0      Duration (in seconds)  What is your age (# years)?
# 1                        121                        30-34
# 2                        462                        30-34
# 3                        293                        18-21
# 4                        851                        55-59
# ...                      ...                          ...
# 23993                    331                        22-24
# 23994                    330                        60-69
# 23995                    860                        25-29
# 23996                    597                        35-39
# 23997                    303                        18-21
#
#                                            Q3  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# ...

# %%
survey_raw.head(5)
# Out:
#    Duration (in seconds)                           Q2  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    121                        30-34
# 2                    462                        30-34
# 3                    293                        18-21
# 4                    851                        55-59
#
#                                        Q3  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
# 2                                     Man
# 3                                     Man
# 4                                     Man
#
#                                           Q4  \
# 0  In which country do you currently reside?
# 1                                      India
# 2                                    Algeria
# 3                                      Egypt
# 4                                     France
#
#                                                   Q5  \
# ...

# %%
survey_raw.shape
# Out:
# (23998, 296)

# %%
survey_copy=survey_raw.copy()

# %%
survey_copy
# Out:
#        Duration (in seconds)                           Q2  \
# 0      Duration (in seconds)  What is your age (# years)?
# 1                        121                        30-34
# 2                        462                        30-34
# 3                        293                        18-21
# 4                        851                        55-59
# ...                      ...                          ...
# 23993                    331                        22-24
# 23994                    330                        60-69
# 23995                    860                        25-29
# 23996                    597                        35-39
# 23997                    303                        18-21
#
#                                            Q3  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# ...

# %%
survey_copy = survey_raw[
    (survey_raw["Q5"] == "No") & 
    (survey_raw["Q24"].notnull()) &
    (survey_raw["Q23"] != "Currently not employed")
]

# %%
survey_copy
# Out:
#       Duration (in seconds)     Q2     Q3                        Q4  Q5  \
# 4                       851  55-59    Man                    France  No
# 8                       501  30-34    Man                   Germany  No
# 9                       787    70+    Man                 Australia  No
# 11                      470  55-59    Man               South Korea  No
# 14                     1132  40-44    Man  United States of America  No
# ...                     ...    ...    ...                       ...  ..
# 23985                   540  40-44    Man  United States of America  No
# 23990                   603  35-39    Man                     India  No
# 23991                   557  40-44    Man                     India  No
# 23995                   860  25-29    Man                    Turkey  No
# 23996                   597  35-39  Woman                    Israel  No
#
#            Q6_1 Q6_2                  Q6_3      Q6_4     Q6_5  ...  \
# ...

# %%
survey_copy.shape
# Out:
# (9094, 296)

# %%
Percentage_of_professional =(survey_copy.shape[0])*100/(survey_raw.shape[0])

# %%
round(Percentage_of_professional,1)
# Out:
# 37.9

# %% [markdown]
# ## Current status of Machine Learning adoptation in different industry

# %%
employee_company=survey_copy.Q24.value_counts()
employee_company
# Out:
# Computers/Technology                      2321
# Academics/Education                       1447
# Accounting/Finance                         802
# Other                                      750
# Manufacturing/Fabrication                  561
# Medical/Pharmaceutical                     509
# Government/Public Service                  500
# Online Service/Internet-based Services     461
# Retail/Sales                               398
# Energy/Mining                              320
# Insurance/Risk Assessment                  256
# Marketing/CRM                              246
# Non-profit/Service                         194
# Broadcasting/Communications                179
# Shipping/Transportation                    150
# Name: Q24, dtype: int64

# %%
employee_company_percentage = round(survey_copy['Q24'].value_counts() * 100 / survey_copy['Q24'].count(),2)
employee_company_percentage
# Out:
# Computers/Technology                      25.52
# Academics/Education                       15.91
# Accounting/Finance                         8.82
# Other                                      8.25
# Manufacturing/Fabrication                  6.17
# Medical/Pharmaceutical                     5.60
# Government/Public Service                  5.50
# Online Service/Internet-based Services     5.07
# Retail/Sales                               4.38
# Energy/Mining                              3.52
# Insurance/Risk Assessment                  2.82
# Marketing/CRM                              2.71
# Non-profit/Service                         2.13
# Broadcasting/Communications                1.97
# Shipping/Transportation                    1.65
# Name: Q24, dtype: float64

# %%
plt.figure(figsize=(10, 10))
plt.title("Current status of Machine Learning in different Industry")
df=sns.barplot(y= employee_company.index,x=employee_company)
df.set(xlabel='No. of responses');

# %%
# Calculate the percentage distribution
employee_company_percentage = survey_copy['Q24'].value_counts() * 100 / survey_copy['Q24'].count()

# Create a pie chart
plt.figure(figsize=(10, 10))
plt.pie(employee_company_percentage, labels=employee_company_percentage.index, autopct='%1.1f%%', startangle=140)
plt.title('Current status of Machine Learning in different Industry')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## Country Participation

# %%
country_df=survey_copy['Q4'].value_counts().head(10)
country_df
# Out:
# India                                                   2678
# United States of America                                1586
# Other                                                    579
# Japan                                                    370
# Brazil                                                   315
# Nigeria                                                  168
# France                                                   160
# United Kingdom of Great Britain and Northern Ireland     150
# Spain                                                    150
# Mexico                                                   149
# Name: Q4, dtype: int64

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(8,8 ))
plt.title("Top 10 participated Country")
plt.xticks(rotation=75)
df=sns.barplot(y= country_df.index,x=country_df)
df.set(xlabel='No. of responses');

# %% [markdown]
# ## AI adoption in different company (According to size)

# %%
AI_adoption = {
    "No (we do not use ML methods)": "Not Started" , 
    "We are exploring ML methods (and may one day put a model into production)": "Exploration Stage",
    "We use ML methods for generating insights (but do not put working models into production)": "Generating Insights", 
    "We recently started using ML methods (i.e., models in production for less than 2 years)": "Models in Production",
    "We have well established ML methods (i.e., models in production for more than 2 years)": "Advanced Stage",
    "I do not know": "Not Known",
    np.nan: "Not Known"
}


map_company_size = {
    "0-49 employees": "1. 0-49 employees" , 
    "50-249 employees": "2. 50-249 employees",
    "250-999 employees": "3. 250-999 employees",
    "1000-9,999 employees": "4. 1000-9,999 employees",
    "10,000 or more employees": "5. 10,000 or more employees",
    np.nan: np.nan   
}

# %%
# Assign more general categories to the state of Machine Learning Adoption in industry
survey_copy["ML_adoption_class"] = survey_copy["Q27"].map(AI_adoption)

survey_copy["AI_adoption_company"] =survey_copy["Q25"].map(map_company_size)
# Out:
# C:\Users\sdutt\AppData\Local\Temp\ipykernel_13292\3103747365.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_copy["ML_adoption_class"] = survey_copy["Q27"].map(AI_adoption)
# C:\Users\sdutt\AppData\Local\Temp\ipykernel_13292\3103747365.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey_copy["AI_adoption_company"] =survey_copy["Q25"].map(map_company_size)

# %%
#sns.countplot( x= survey_copy.ML_adoption_class, hue=survey_copy.AI_adoption_company, palette='Set1')

# %%
# Create a pivot table from your data
pivot_table = pd.pivot_table(survey_copy, index='AI_adoption_company', columns='ML_adoption_class', aggfunc='size', fill_value=0)

# Create a heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_table, annot=True, fmt='d', cmap='YlGnBu')

# Add labels and a title
plt.xlabel('ML Adoption Class')
plt.ylabel('AI Adoption Company')
plt.title('Heatmap of ML Adoption Class by AI Adoption Company')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a pivot table from your data
pivot_table = pd.pivot_table(survey_copy, index='AI_adoption_company', columns='ML_adoption_class', aggfunc='size', fill_value=0)

# Calculate the percentages for each cell in the pivot table
# total_counts = pivot_table.sum().sum()  # Total count of all responses
# percentages = (pivot_table / total_counts) * 100  # Calculate percentages

row_percentages = pivot_table.div(pivot_table.sum(axis=1), axis=0) * 100
# Create a heatmap with percentages
plt.figure(figsize=(12, 6))
sns.heatmap(row_percentages, annot=True, fmt='.2f', cmap='YlGnBu')

# Add labels and a title
plt.xlabel('ML Adoption Class')
plt.ylabel('AI Adoption Company')
plt.title('Distribution of ML Adoption Stages Across Company Sizes')

# Show the plot
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# From this heatmap, it can easily seen that Major industry are now working with advance stage,basically they are the AI adopters.While the industries with less than 50 employees not even statred working with AI.
# Around 32% large industries already shift their working sight to the modern technology.
# The trend suggests that all the company irrespective of their employee size tends to adopt AI.

# %% [markdown]
# ## AI adoption in different sectors

# %%
# #Create pivot table
# pivot_sector=pd.pivot_table(survey_copy,index='ML_adoption_class',columns='Q24',aggfunc='size',fill_value=0)

# plt.figure(figsize=(12,6))
# sns.heatmap(pivot_sector,annot=True,fmt="d",cmap="Blues");

# # Add labels and a title
# plt.xlabel('ML Adoption Stage')
# plt.ylabel('AI Adoption in different sector')
# plt.title('Heatmap of ML Adoption Stage by different sector')

# # Show the plot
# plt.tight_layout()
# plt.show()

# %% [markdown]
# pivot_table.sum(axis=1): This part calculates the sum of each row in the pivot_table. The axis=1 argument specifies that the sum should be computed along the rows (horizontally). So, for each row in pivot_table, it calculates the sum of values across the columns, which represents the total count for that particular "AI Adoption Company."
#
# pivot_table.div(...): This part performs element-wise division between the pivot_table and the row sums calculated in the previous step. The div function divides each element in pivot_table by the corresponding row sum. This division operation normalizes the counts in each cell to represent percentages.
#
# * 100: After the division, we multiply the result by 100 to convert the fractions into percentages. This scaling ensures that the values in the row_percentages DataFrame are expressed as percentages (e.g., 0.10 becomes 10%).

# %%
pivot_sector

column_percentage=pivot_sector.div(pivot_sector.sum(axis=1),axis=0)*100
column_percentage
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 pivot_sector
#       3 column_percentage=pivot_sector.div(pivot_sector.sum(axis=1),axis=0)*100
#       4 column_percentage
#
# NameError: name 'pivot_sector' is not defined

# %%
plt.figure(figsize=(12,6))
plt.title('Distribution of Industry Sectors across AI adoption Stages')
sns.heatmap(column_percentage,annot=True,fmt=".2f",cmap="YlGnBu")
plt.xlabel('ML Adoption Stage')
plt.ylabel('AI Adoption in different sector')
plt.tight_layout;

# %% [markdown]
# As, we find from the previous data most of the participants are from Computer/Technology sectors. so there is a chance of biasness of data.

# %% [markdown]
# ## AI Technology Tech

# %% [markdown]
# ### Data Storage

# %%
def usage_of_a_product_or_service(question_title: str, row: pd.Series, columns_list: list) -> str:
    """It takes as input a question title with multiple choices answers and checks
    if the respondent has selected at least one of the answers or not. 
    For instance, if we want to check if a respondent uses cloud computing platforms, question 31, then we should 
    check if the participant has selected any cloud computing platform choice Q31_1, Q31_2, etc. 
    """
    for col in columns_list:
        if col.startswith(question_title):

            if not pd.isnull(row[col]) and row[col].strip().lower() != "none":
                return "Yes"
    # If all the columns (choices), Q31_1, Q31_2, etc have empty values then the user hasn't selected 
    # any platform so we return NO as the answer
    return "No"

# %%
survey_copy['Data_Storage_Tool']=survey_copy.apply(lambda row:usage_of_a_product_or_service("Q31",row,list(survey_copy.columns)),axis=1)

# %%
survey_copy.Data_Storage_Tool

# %%
lang_df=survey_copy['Q12'].value_counts().head(10)
lang_df

# %%
# Assuming your DataFrame is named survey_copy
# Replace 'Q13_' with the actual prefix of your columns
# You can also use regex to filter columns if needed
language_cols = survey_copy.filter(like='Q12_')

# Reshape the DataFrame using melt
melted_df = pd.melt(language_cols, value_name='Language').dropna()['Language']

# Count the occurrences of each language
language_counts = melted_df.value_counts()


# Display the result
print(language_counts)
# Out:
# Python        7266
# SQL           4306
# R             1931
# Javascript    1366
# C++           1248
# Java          1208
# C             1036
# Bash          1000
# MATLAB         827
# Other          729
# C#             659
# PHP            509
# Go             159
# Julia          137
# None           131
# Name: Language, dtype: int64

# %%
sns.barplot(y=language_counts.index,x=language_counts);

# %%
# Assuming your DataFrame is named survey_copy
# Replace 'Q13_' with the actual prefix of your columns
# You can also use regex to filter columns if needed
IDE_cols = survey_copy.filter(like='Q13_')

# Reshape the DataFrame using melt
melted_df = pd.melt(IDE_cols, value_name='Language').dropna()['Language']

# Count the occurrences of each language
IDE_counts = melted_df.value_counts()
IDE_counts
# Out:
#  Jupyter Notebook                5536
#  Visual Studio Code (VSCode)     3714
#  PyCharm                         2237
# JupyterLab                       2156
#   Notepad++                      1813
#  Visual Studio                   1617
#  RStudio                         1605
#   Spyder                         1183
#   Sublime Text                    872
#   Vim / Emacs                     834
#  MATLAB                           694
# IntelliJ                          611
# Other                             586
# None                              175
# Name: Language, dtype: int64

# %%
sns.barplot(y=IDE_counts.index,x=IDE_counts);

# %%
ml_framework=survey_copy.filter(like ="Q17_")

melted_df=pd.melt(ml_framework, value_name= "Framework").dropna()["Framework"]
framework=melted_df.value_counts()
framework
# Out:
#   Scikit-learn         5231
#   TensorFlow           3403
#  Keras                 2890
#  Xgboost               2429
#  PyTorch               2372
#  LightGBM              1185
#  Huggingface            792
#  CatBoost               648
# None                    575
#  PyTorch Lightning      480
#  Caret                  470
#  Fast.ai                327
# Other                   301
#  Tidymodels             298
#  JAX                     97
# Name: Framework, dtype: int64

# %%
sns.barplot(y=framework.index,x=framework);
